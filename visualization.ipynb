# %%
import matplotlib.pyplot as plt

# train_acc和test_acc分别存储在train_acc_list和test_acc_list中
train_acc_list = [0.585, 0.799, 0.826, 0.844, 0.861, 0.875, 0.883, 0.888, 0.895, 0.898, 
                  0.902, 0.905, 0.909, 0.911, 0.913, 0.915, 0.917, 0.920, 0.922, 0.924, 
                  0.924, 0.927, 0.928, 0.929, 0.931, 0.932, 0.932, 0.933, 0.936, 0.936]
test_acc_list = [0.726, 0.805, 0.838, 0.853, 0.871, 0.881, 0.885, 0.894, 0.901, 0.903, 
                 0.904, 0.905, 0.909, 0.913, 0.912, 0.907, 0.916, 0.915, 0.910, 0.921, 
                 0.919, 0.924, 0.922, 0.913, 0.920, 0.923, 0.927, 0.919, 0.927, 0.924]
plt.figure(figsize=(12, 8))
# 绘制train_acc和test_acc的折线图
plt.plot(range(1, len(train_acc_list)+1), train_acc_list, label='train_acc')
plt.plot(range(1, len(test_acc_list)+1), test_acc_list, label='test_acc')
# 添加坐标轴标签和图例

plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend()

# 找到test_acc最高的点并标注出来
best_idx = test_acc_list.index(max(test_acc_list))
plt.annotate('best test_acc: {:.3f}'.format(test_acc_list[best_idx]), xy=(best_idx+1, test_acc_list[best_idx]),
             xytext=(best_idx+1, test_acc_list[best_idx]+0.02), ha='center',
             arrowprops=dict(facecolor='black', edgecolor='black', arrowstyle='->', linewidth=1))
# 去掉上边线和右边线
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# 显示图像
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 8))
# train_acc和test_acc分别存储在train_acc_list和test_acc_list中
train_acc_list = [0.585, 0.799, 0.826, 0.844, 0.861, 0.875, 0.883, 0.888, 0.895, 0.898, 
                  0.902, 0.905, 0.909, 0.911, 0.913, 0.915, 0.917, 0.920, 0.922, 0.924, 
                  0.924, 0.927, 0.928, 0.929, 0.931, 0.932, 0.932, 0.933, 0.936, 0.936]
test_acc_list = [0.726, 0.805, 0.838, 0.853, 0.871, 0.881, 0.885, 0.894, 0.901, 0.903, 
                 0.904, 0.905, 0.909, 0.913, 0.912, 0.907, 0.916, 0.915, 0.910, 0.921, 
                 0.919, 0.924, 0.922, 0.913, 0.920, 0.923, 0.927, 0.919, 0.927, 0.924]

# 绘制train_acc和test_acc的折线图
plt.plot(range(1, len(train_acc_list)+1), train_acc_list, label='train_acc')
plt.plot(range(1, len(test_acc_list)+1), test_acc_list, label='test_acc')

# 添加坐标轴标签和图例
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend()

# 找到test_acc最高的点并标注出来
best_idx = test_acc_list.index(max(test_acc_list))
plt.annotate('best: {:.3f}'.format(test_acc_list[best_idx]), xy=(best_idx+1, test_acc_list[best_idx]),
             xytext=(best_idx+1, test_acc_list[best_idx]-0.04), ha='center',
             arrowprops=dict(facecolor='black', shrink=0.5))

# 去掉上边线和右边线
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# 显示图像
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = range(1, 21)
train_acc = [0.884, 0.904, 0.917, 0.927, 0.932, 0.937, 0.945, 0.949, 0.953, 0.958, 0.962, 0.967, 0.971, 0.974, 0.976, 0.979, 0.981, 0.984, 0.984, 0.987]
test_acc = [0.869, 0.841, 0.908, 0.913, 0.913, 0.905, 0.910, 0.913, 0.909, 0.902, 0.921, 0.920, 0.905, 0.916, 0.917, 0.919, 0.917, 0.920, 0.921, 0.921]
plt.figure(figsize=(12, 8)) # 设置图像大小为 12*8
plt.plot(epochs, train_acc, '-o', label='train_acc')
plt.plot(epochs, test_acc, '-o', label='test_acc')
plt.xticks(range(1, len(train_acc) + 1))
best_epoch = test_acc.index(max(test_acc)) + 1
best_acc = max(test_acc)
plt.annotate(f'best epoch: {best_epoch}\nbest test_acc: {best_acc:.3f}', xy=(best_epoch, best_acc), xytext=(best_epoch, best_acc + 0.01), ha='center', va='bottom', arrowprops=dict(arrowstyle='->'))

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Testing Accuracy')
plt.legend()

# %%
import matplotlib.pyplot as plt

test_acc = [92.67, 92.4, 90.23, 89.2]
batchsize = [16, 32, 64, 128]

plt.plot(batchsize, test_acc)

plt.xlabel('batchsize')
plt.ylabel('test_acc')

plt.show()

# %%
# Out:
# True
